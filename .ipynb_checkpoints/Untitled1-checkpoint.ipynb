# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, r2_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report

#from google.colab import drive
#import warnings
#warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams.update({'figure.max_open_warning': 0}) # Hide warnings

# %%
# import the data into datafram
path ="C:/Users/pc/Desktop/1/my project/depression prediction/"
df = pd.read_csv(path + "data.csv")

# %%
df.drop_duplicates(inplace=True)

# %%
new_col = ['age','address','schooling','stud_hr','employed','h_disab',
           'ment_cond','social_hr','fit_hr','wind','dry_mouth',
           'positive','breath_diff','initiate','tremb','worry','look_fwd',
           'down','enthus','life_mean','scared','outcome']
df.columns= new_col

# %%
df.outcome.replace('high signs of depression ', 'High signs of depression ', inplace=True)

# %%
X = df.copy()
y = X.pop("outcome")

# %%
i = lambda x: x.split("-")[-1].strip("hours")[0]
X["social_hr"]=X["social_hr"].apply(i)
X["fit_hr"]=X["fit_hr"].apply(i)

# %%
X.drop(columns=["address", "schooling"], inplace=True)

# %%
mominal_cloumns_mask=X.select_dtypes("object").nunique()>2
mominal_cloumns=mominal_cloumns_mask.index[mominal_cloumns_mask][:-2]

# %%
ordinal_columns_mask=X.select_dtypes(["int64", "float64"]).nunique()==4
ordinal_columns=ordinal_columns_mask.index[ordinal_columns_mask]
for i in mominal_cloumns_mask.index[mominal_cloumns_mask][[3,4]]:
    ordinal_columns=ordinal_columns.insert(0, i)

# %%
numerical_columns_mask=X.select_dtypes(["int64", "float64"]).nunique()>4
numerical_columns=numerical_columns_mask.index[numerical_columns_mask]

# %%
for i in ordinal_columns:
    X[i] = X[i].astype("category")

# %%
precessor = [
    ("ordinal columns", OrdinalEncoder(),ordinal_columns ),
    ("nominal columns", OneHotEncoder(),mominal_cloumns ),
    ("numerical columns", StandardScaler(),numerical_columns )
    
]

# %%
transformer = ColumnTransformer(precessor, remainder="passthrough")

# %%
classfier_names = ["RandomForest", "AdaBoost", "GradientBosst", "Logisticregression", "DecisionTree",
                  "GaussianNB"]

classfiers=[RandomForestClassifier(), AdaBoostClassifier(), GradientBoostingClassifier(),
LogisticRegression(), DecisionTreeClassifier(), GaussianNB()]

# %%
pipelines =[ Pipeline([
    ("transformer", transformer), (classfier_name, classfier)
]) for classfier_name, classfier in zip(classfier_names, classfiers) ]

# %%
scoring = {"acc": "accuracy"}
training_scores = []
cv_scores = {classfier_name:[] for classfier_name in classfier_names}
for classfier_name, pipeline in zip(classfier_names, pipelines):
    cv_score = cross_validate(estimator=pipeline, X=X, y=y, cv=4, error_score='raise', scoring=scoring,
                         return_estimator=True, return_train_score=True)
    training_score = np.mean(cv_score["train_acc"]) * 100
    training_scores.append(training_score)
    cv_scores[classfier_name]=cv_score
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\pc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
training_scores
# Out:
# [97.25274725274726,
#  65.84249084249085,
#  97.25274725274726,
#  83.1201585299946,
#  97.25274725274726,
#  67.48333633579536]

# %%
cv_scores
# Out:
# {'RandomForest': {'fit_time': array([0.32641912, 0.30179524, 0.38644218, 0.36155319]),
#   'score_time': array([0.04964828, 0.04804349, 0.05422401, 0.04036212]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('RandomForest', RandomForestClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('RandomForest', RandomForestClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('RandomForest', RandomForestClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('RandomForest', RandomForestClassifier())])],
#   'test_acc': array([0.72131148, 0.80327869, 0.81967213, 0.66666667]),
#   'train_acc': array([0.98901099, 0.95054945, 0.95054945, 1.        ])},
#  'AdaBoost': {'fit_time': array([0.20551062, 0.21722651, 0.23565698, 0.19871545]),
#   'score_time': array([0.02602625, 0.03586459, 0.04922152, 0.03314257]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('AdaBoost', AdaBoostClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('AdaBoost', AdaBoostClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('AdaBoost', AdaBoostClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('AdaBoost', AdaBoostClassifier())])],
#   'test_acc': array([0.6557377 , 0.67213115, 0.67213115, 0.63333333]),
#   'train_acc': array([0.65934066, 0.65384615, 0.65384615, 0.66666667])},
#  'GradientBosst': {'fit_time': array([1.00047994, 1.57189584, 1.53195572, 1.33180857]),
#   'score_time': array([0.02947354, 0.03493237, 0.03156543, 0.01460314]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GradientBosst', GradientBoostingClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GradientBosst', GradientBoostingClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GradientBosst', GradientBoostingClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GradientBosst', GradientBoostingClassifier())])],
#   'test_acc': array([0.73770492, 0.78688525, 0.7704918 , 0.66666667]),
#   'train_acc': array([0.98901099, 0.95054945, 0.95054945, 1.        ])},
#  'Logisticregression': {'fit_time': array([0.29168057, 0.21835303, 0.37082911, 0.23988152]),
#   'score_time': array([0.02346563, 0.050771  , 0.03304696, 0.02403235]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('Logisticregression', LogisticRegression())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('Logisticregression', LogisticRegression())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('Logisticregression', LogisticRegression())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('Logisticregression', LogisticRegression())])],
#   'test_acc': array([0.6557377 , 0.70491803, 0.70491803, 0.65      ]),
#   'train_acc': array([0.81318681, 0.82417582, 0.8021978 , 0.8852459 ])},
#  'DecisionTree': {'fit_time': array([0.03911328, 0.04807687, 0.06699395, 0.03339934]),
#   'score_time': array([0.02497911, 0.02389479, 0.0161643 , 0.01747751]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('DecisionTree', DecisionTreeClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('DecisionTree', DecisionTreeClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('DecisionTree', DecisionTreeClassifier())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('DecisionTree', DecisionTreeClassifier())])],
#   'test_acc': array([0.62295082, 0.73770492, 0.72131148, 0.61666667]),
#   'train_acc': array([0.98901099, 0.95054945, 0.95054945, 1.        ])},
#  'GaussianNB': {'fit_time': array([0.03371334, 0.03436804, 0.0496676 , 0.0342977 ]),
#   'score_time': array([0.0339818 , 0.03350401, 0.01665235, 0.01684666]),
#   'estimator': [Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GaussianNB', GaussianNB())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GaussianNB', GaussianNB())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GaussianNB', GaussianNB())]),
#    Pipeline(steps=[('transformer',
#                     ColumnTransformer(remainder='passthrough',
#                                       transformers=[('ordinal columns',
#                                                      OrdinalEncoder(),
#                                                      Index(['fit_hr', 'social_hr', 'wind', 'dry_mouth', 'positive', 'breath_diff',
#           'initiate', 'tremb', 'worry', 'look_fwd', 'down', 'enthus', 'life_mean',
#           'scared'],
#          dtype='object')),
#                                                     ('nominal columns',
#                                                      OneHotEncoder(),
#                                                      Index(['employed', 'h_disab', 'ment_cond'], dtype='object')),
#                                                     ('numerical columns',
#                                                      StandardScaler(),
#                                                      Index(['age', 'stud_hr'], dtype='object'))])),
#                    ('GaussianNB', GaussianNB())])],
#   'test_acc': array([0.57377049, 0.60655738, 0.70491803, 0.56666667]),
#   'train_acc': array([0.6043956 , 0.68681319, 0.68681319, 0.72131148])}}
